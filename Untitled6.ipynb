# %% [markdown]
# # **Data Science Intern @ LetsGrowMore**

# %% [markdown]
# ## **Author : M ACHYUTH KUMAR**

# %% [markdown]
# ### **Image to Pencil Sketch with Python:**

# %% [markdown]
# **Importing Required libraries**

# %%
# !pip install openCV-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: openCV-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from openCV-python) (1.22.4)

# %% [markdown]
# **Loading Image**

# %%
import cv2
import numpy as np

# %%
img=cv2.imread("dog.jpg")
img
# Out:
# array([[[163, 100,  62],
#         [163, 100,  62],
#         [162,  99,  61],
#         ...,
#         [169, 127, 114],
#         [169, 127, 114],
#         [169, 127, 114]],
#
#        [[163, 100,  62],
#         [163, 100,  62],
#         [162,  99,  61],
#         ...,
#         [169, 127, 114],
#         [169, 127, 114],
#         [169, 127, 114]],
#
#        [[162,  99,  61],
#         [162,  99,  61],
#         [162,  98,  63],
#         ...,
#         [168, 127, 112],
#         [168, 127, 112],
#         [168, 127, 112]],
#
#        ...,
#
#        [[149,  91,  55],
#         [153,  95,  59],
#         [157, 100,  61],
#         ...,
#         [149, 103,  72],
#         [162, 116,  85],
#         [161, 114,  83]],
#
#        [[150,  92,  56],
#         [155,  97,  61],
#         [160, 103,  64],
#         ...,
#         [157, 110,  79],
#         [161, 114,  83],
#         [159, 112,  81]],
#
#        [[151,  93,  57],
#         [156,  98,  62],
#         [162, 105,  66],
#         ...,
#         [167, 118,  86],
#         [161, 112,  80],
#         [162, 113,  81]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# **Converting Image into Gray Scale**

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray
# Out:
# array([[ 96,  96,  95, ..., 128, 128, 128],
#        [ 96,  96,  95, ..., 128, 128, 128],
#        [ 95,  95,  95, ..., 127, 127, 127],
#        ...,
#        [ 87,  91,  95, ...,  99, 112, 110],
#        [ 88,  93,  98, ..., 106, 110, 108],
#        [ 89,  94, 100, ..., 114, 108, 109]], dtype=uint8)

# %%
plt.imshow(img_gray)

# %% [markdown]
# **Inverting the image**

# %%
img_invert = cv2.bitwise_not(img_gray)
img_invert
# Out:
# array([[159, 159, 160, ..., 127, 127, 127],
#        [159, 159, 160, ..., 127, 127, 127],
#        [160, 160, 160, ..., 128, 128, 128],
#        ...,
#        [168, 164, 160, ..., 156, 143, 145],
#        [167, 162, 157, ..., 149, 145, 147],
#        [166, 161, 155, ..., 141, 147, 146]], dtype=uint8)

# %%
plt.imshow(img_invert)

# %% [markdown]
# **Smoothing the image**

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
img_smoothing
# Out:
# array([[160, 160, 160, ..., 127, 127, 127],
#        [160, 160, 160, ..., 127, 127, 127],
#        [160, 160, 160, ..., 127, 127, 127],
#        ...,
#        [160, 160, 159, ..., 137, 137, 138],
#        [160, 160, 159, ..., 138, 139, 139],
#        [160, 159, 159, ..., 139, 139, 139]], dtype=uint8)

# %%
plt.imshow(img_smoothing)

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256.0)

# %% [markdown]
# **Final** **Sketch**

# %%
final_img = dodgeV2(img_gray, img_smoothing)
plt.imshow(final_img)

# %%
cv2.imshow("Sketch", pencil_sketch)
cv2.waitKey(0)

# %% [markdown]
# ### **Thank You , LetsGrowMore**
